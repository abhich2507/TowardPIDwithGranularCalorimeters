# %%
import matplotlib.pyplot as plt
import pickle

with open('plot_pik.pkl', 'rb') as f:
    loaded_fig = pickle.load(f)
# Out:
# <div id='d624821d-6b08-4831-b803-eb3c9c69d768'></div>

# %%
plt.rcParams['legend.framealpha'] = 0.3
for ax in loaded_fig.axes:
    # Modify the legend for each subplot (example: set transparency)
    legend = ax.get_legend()
    plt.legend(framealpha=0.2)
    # if legend:  # Ensure the subplot has a legend
    #     legend.set_framealpha(0.5)  # Change legend transparency (0: fully transparent, 1: opaque)

# Show the modified figure
loaded_fig.tight_layout()  # Adjust layout for better spacing
# Save the modified figure as a PDF
loaded_fig.savefig("modified_plot.pdf", dpi=300, bbox_inches='tight')
# Out:
# <div id='be1bfb41-8a5b-4e88-807f-cf97929c96ef'></div>
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

with open('plot_pk.pkl', 'rb') as f:
    loaded_fig_pk = pickle.load(f)

# loaded_fig_pk

# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# Load the figure from the pickle file
with open('plot_pik.pkl', 'rb') as f:
    loaded_fig_pk = pickle.load(f)

# Set font size for axis titles, labels, and legend
font_size = 20
# loaded_fig_pk.set_size_inches(10, 8)
# Loop through each axis to modify properties
for ax in loaded_fig_pk.axes:
    # Set axis titles and labels
    ax.set_xlabel(ax.get_xlabel(), fontsize=font_size)  # X-axis label
    ax.set_ylabel(ax.get_ylabel(), fontsize=font_size)  # Y-axis label
    
    # Set font size for tick labels
    ax.tick_params(axis='both', which='major', labelsize=font_size)
    
    # Set the legend font size and remove title from the legend
    ax.legend(fontsize=14)  # Set legend font size   


    # Remove the plot title if any
    ax.set_title("")  # This removes the plot title if there is one

# Show the modified figure
loaded_fig_pk.tight_layout()  # Adjust layout to prevent label overlap
# plt.show()
plt.savefig("modified_plot_pik.pdf", dpi=300, bbox_inches='tight')

# Optionally, save the modified figure as a PDF
# loaded_fig_pk.savefig("modified_plot.pdf", dpi=300, bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pickle
import matplotlib.pyplot as plt

# Load the two pickle files
with open('plot_pk.pkl', 'rb') as f:
    fig1 = pickle.load(f)

with open('plot_pik.pkl', 'rb') as f:
    fig2 = pickle.load(f)

# %%
print(type(fig1))

# Create a new figure with 4 subplots (shared x-axis for the first plot)
# fig, axs = plt.subplots(2, 1, sharex=True, figsize=(10, 8))  # Adjust figsize as needed

# Extract the first plot from both loaded figures
ax1_1 = fig1.axes[0]  # First plot from plot1_pk.pkl
ax2_1 = fig2.axes[0]  # First plot from plot2_pk.pkl
ax1_1.plot(ax1_1.get_lines()[0].get_xdata(), ax1_1.get_lines()[0].get_ydata(), label='Plot 1 - First', color='b')
print(ax1_1.get_lines()[0].get_xdata())
plt.show()

# Plot the first subplot with shared x-axis
# # Copy data from the first plot in both figures
# ax1_1.plot(ax1_1.get_lines()[0].get_xdata(), ax1_1.get_lines()[0].get_ydata(), label='Plot 1 - First', color='b')
# ax2_1.plot(ax2_1.get_lines()[0].get_xdata(), ax2_1.get_lines()[0].get_ydata(), label='Plot 2 - First', color='g')

# # Add legend for the first subplot (with shared x-axis)
# axs[0, 0].legend()

# # For the remaining subplots, plot the second, third, and fourth plots from the loaded figures
# # axs[0, 1].plot(fig1.axes[1].get_lines()[0].get_xdata(), fig1.axes[1].get_lines()[0].get_ydata())
# # axs[1, 0].plot(fig1.axes[2].get_lines()[0].get_xdata(), fig1.axes[2].get_lines()[0].get_ydata())
# # axs[1, 1].plot(fig1.axes[3].get_lines()[0].get_xdata(), fig1.axes[3].get_lines()[0].get_ydata())

# # You can also plot data from `fig2` if necessary in these subplots:
# # axs[0, 1].plot(fig2.axes[1].get_lines()[0].get_xdata(), fig2.axes[1].get_lines()[0].get_ydata())

# # Adjust the layout to prevent overlapping
# fig.tight_layout()

# # Show the new figure
# plt.show()
# Out:
# <class 'matplotlib.figure.Figure'>
# [900.0 144.0 36.0 9.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import gridspec

# Simple data to display in various forms
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

fig = plt.figure()
# set height ratios for subplots
gs = gridspec.GridSpec(2, 1, height_ratios=[2, 1]) 

# the first subplot
ax0 = plt.subplot(gs[0])
# log scale for axis Y of the first subplot
ax0.set_yscale("log")
line0, = ax0.plot(x, y, color='r')

# the second subplot
# shared axis X
ax1 = plt.subplot(gs[1], sharex = ax0)
line1, = ax1.plot(x, y, color='b', linestyle='--')
plt.setp(ax0.get_xticklabels(), visible=False)
# remove last tick label for the second subplot
yticks = ax1.yaxis.get_major_ticks()
yticks[-1].label1.set_visible(False)

# put legend on first subplot
ax0.legend((line0, line1), ('red line', 'blue line'), loc='lower left')

# remove vertical gap between subplots
plt.subplots_adjust(hspace=.0)
plt.show()
